# %%
# Dependencies
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# %%
types_df = pd.read_csv("output_data/city_data.csv")
types_df.head()
# Out:
#    Unnamed: 0         City  Latitude  Longitude  Temperature  Humidity  \
# 0           0   Bredasdorp    -34.53      20.04        51.80        87
# 1           1         Brae     60.40      -1.35        55.40        76
# 2           2  San Quintín     30.48    -115.95        68.20        80
# 3           3        Nioro     13.35     -15.75        86.11        56
# 4           4         Daru     -9.08     143.21        77.49        87
#
#    Cloudiness  Wind Speed
# 0           5       12.75
# 1          20       10.29
# 2           0        2.44
# 3         100        6.73
# 4         100       17.69

# %%
types_df.to_html("Table.htm")

# %%
html_file = types_df.to_html()

# %%
print(types_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temperature</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Bredasdorp</td>
#       <td>-34.53</td>
#       <td>20.04</td>
#       <td>51.80</td>
#       <td>87</td>
#       <td>5</td>
#       <td>12.75</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Brae</td>
#       <td>60.40</td>
#       <td>-1.35</td>
#       <td>55.40</td>
#       <td>76</td>
#       <td>20</td>
#       <td>10.29</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>San Quintín</td>
#       <td>30.48</td>
#       <td>-115.95</td>
#       <td>68.20</td>
#       <td>80</td>
#       <td>0</td>
# ...

# %%
types_df.head()
# Out:
#    Unnamed: 0         City  Latitude  Longitude  Temperature  Humidity  \
# 0           0   Bredasdorp    -34.53      20.04        51.80        87
# 1           1         Brae     60.40      -1.35        55.40        76
# 2           2  San Quintín     30.48    -115.95        68.20        80
# 3           3        Nioro     13.35     -15.75        86.11        56
# 4           4         Daru     -9.08     143.21        77.49        87
#
#    Cloudiness  Wind Speed
# 0           5       12.75
# 1          20       10.29
# 2           0        2.44
# 3         100        6.73
# 4         100       17.69

# %%
table_df = types_df.drop(columns=['Unnamed: 0'])

# %%
table_df.head()
# Out:
#           City  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0   Bredasdorp    -34.53      20.04        51.80        87           5
# 1         Brae     60.40      -1.35        55.40        76          20
# 2  San Quintín     30.48    -115.95        68.20        80           0
# 3        Nioro     13.35     -15.75        86.11        56         100
# 4         Daru     -9.08     143.21        77.49        87         100
#
#    Wind Speed
# 0       12.75
# 1       10.29
# 2        2.44
# 3        6.73
# 4       17.69

# %%
table_df.to_html("Table.htm")
html_file = table_df.to_html() 
print(table_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temperature</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bredasdorp</td>
#       <td>-34.53</td>
#       <td>20.04</td>
#       <td>51.80</td>
#       <td>87</td>
#       <td>5</td>
#       <td>12.75</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Brae</td>
#       <td>60.40</td>
#       <td>-1.35</td>
#       <td>55.40</td>
#       <td>76</td>
#       <td>20</td>
#       <td>10.29</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>San Quintín</td>
#       <td>30.48</td>
#       <td>-115.95</td>
#       <td>68.20</td>
#       <td>80</td>
#       <td>0</td>
#       <td>2.44</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Nioro</td>
# ...
